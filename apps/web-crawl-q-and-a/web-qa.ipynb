# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "vw.com"
full_url = "https://vw.com/"

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        # Create a list to store the hyperlinks
        self.hyperlinks = []

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)

        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser()
    parser.feed(html)

    return parser.hyperlinks

# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))


def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress

        # Save text from the url to a <url>.txt file
        with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w") as f:

            # Get the text from the URL using BeautifulSoup
            soup = BeautifulSoup(requests.get(url).text, "html.parser")

            # Get the text but remove the tags
            text = soup.get_text()

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")
            
            # Otherwise, write the text to the file in the text directory
            f.write(text)

        # Get the hyperlinks from the URL and add them to the queue
        for link in get_domain_hyperlinks(local_domain, url):
            if link not in seen:
                queue.append(link)
                seen.add(link)

# %%
crawl(full_url)
# Out:
# https://vw.com/
# https://vw.com/en/inventory.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/tiny-home-movement.html
# https://vw.com/en/newsroom/everything-electric/on-the-road-charging-experience.html
# https://vw.com/en/newsroom/everything-electric.html
# https://vw.com/en/newsroom/discover-vw.html
# https://vw.com/en/newsroom/discover-vw/iq-drive.html
# https://vw.com/en/newsroom/discover-vw/keeping-driving-fun-alive-in-the-2022-volkswagen-golf-gti-and-golf-r.html
# https://vw.com/en/newsroom/discover-vw/car-maintenance.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/scenic-drives.html
# https://vw.com/en/newsroom/discover-vw/meet-vws-expanding-suv-lineup.html
# https://vw.com/en/models/taos.html
# https://vw.com/en/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/javascript:window.open("/en/builder.html/__app/taos.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/taos.app", "_self");' (found at least ' ')
# https://vw.com/en/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/iq-drive.html
# https://vw.com/en/models/arteon.html
# https://vw.com/javascript:window.open("/en/builder.html/__app/arteon.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/arteon.app", "_self");' (found at least ' ')
# https://vw.com/en/models/arteon.html/__layer/layers/showrooms/arteon/_2023/driver-assistance/master.layer
# https://vw.com/en/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/en/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/golf-r.html
# https://vw.com/en/models/golf-r.html/__layer/layers/showrooms/golf_r/_2023/driver-assistance/master.layer
# https://vw.com/javascript:window.open("/en/builder.html/__app/golf-r.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/golf-r.app", "_self");' (found at least ' ')
# https://vw.com/en/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/en/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/models/golf-gti.html
# https://vw.com/en/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/models/golf-gti.html/__layer/layers/showrooms/golf_gti/_2023/driver-assistance/master.layer
# https://vw.com/en/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/javascript:window.open("/en/builder.html/__app/golf-gti.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/golf-gti.app", "_self");' (found at least ' ')
# https://vw.com/en/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/taos.html/__layer/layers/showrooms/taos/_2023/driver-assistance/master.layer
# https://vw.com/en/models/tiguan.html
# https://vw.com/en/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/en/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/tiguan.html/__layer/layers/showrooms/tiguan/_2023/driver-assistance/master.layer
# https://vw.com/javascript:window.open("/en/builder.html/__app/tiguan.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/tiguan.app", "_self");' (found at least ' ')
# https://vw.com/en/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/models/id-4.html
# https://vw.com/en/models/id-4.html/__layer/layers/showrooms/id_4/_2023/driver-assistance/master.layer
# https://vw.com/en/models/id-4.html/__layer/layers/showrooms/id_4/_2023/car-net-myvw-id-4/master.layer
# https://vw.com/en/financial-services/take-it-ev.html
# https://vw.com/javascript:window.open("/en/offers.html?model=ID.4","_self");
# HTTP Error 404: Not Found
# https://vw.com/javascript:window.open("/en/builder.html/__app/id-4.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/en/builder.html/__app/id-4.app", "_self");' (found at least ' ')
# https://vw.com/en/electric-vehicles/electric-vehicles-articles.html#inside-id4
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/switch-to-ev.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/auto-shop-in-the-ev-era.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-range.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-fuel-economy.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-owning-costs.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/what-you-want-in-your-electric-warranty.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/common-misconceptions-about-electric-vehicles.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-charging-costs.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-batteries.html
# https://vw.com/en/electric-vehicles/electric-vehicles-articles/ev-charging-time.html
# https://vw.com/en/models/id-buzz.html
# https://vw.com/en/suv.html
# https://vw.com/en/models/id-buzz.html/__layer/layers/showrooms/id_buzz/reveal_1902959974/wallpapers/wallpapers/master.layer
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/desktop/download/IDBuzz_2048x1152_LemonYellow-v2.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/mobile/download/IDBuzz_1152x2048_FloridaBlue.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/mobile/download/IDBuzz_1152x2048_EnergeticOrange-v2.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/mobile/download/IDBuzz_1152x2048_LemonYellow-v2.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/mobile/download/IDBuzz_1152x2048_EnergeticOrange.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/desktop/download/IDBuzz_2048x21152_EnergeticOrange-v2.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/desktop/download/IDBuzz_2048x1152_BayLeafGreen.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/desktop/download/IDBuzz_2048x1152_FloridaBlue-v1.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/mobile/download/IDBuzz_1152x2048_BayLeafGreen.png
# https://vw.com/idhub/content/dam/onehub_pkw/importers/us/en/showrooms/id-buzz/reveal/wallpapers/desktop/download/IDBuzz_2048x1152_EnergeticOrange.png
# https://vw.com/en/models/id-7.html
# https://vw.com/en/models/id-7.html#form
# https://vw.com/en/electric-vehicles/electric-vehicles-articles.html#intro-evs
# https://vw.com/en/models/id-4.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/en/models/id-4.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/en/newsroom/discover-vw/americans-love-suvs.html
# https://vw.com/en/newsroom/discover-vw/taos-reveal.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/vw-names.html
# https://vw.com/en/newsroom/future-of-mobility/proof-of-concept.html
# https://vw.com/en/newsroom/future-of-mobility/tarok-concept.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/8-coolest-concept-cars.html
# https://vw.com/en/newsroom/future-of-mobility/drive-bigger-hello-light.html
# https://vw.com/en/newsroom/everything-electric/id-buzz-intro.html
# https://vw.com/en/newsroom/everything-electric/ev-q-a.html
# https://vw.com/en/newsroom/future-of-mobility/what-becoming-carbon-neutral-means-to-volkswagen-and-why-its-the-only-way-forward.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/70-years-of-vw-in-the-u-s.html
# https://vw.com/en/newsroom/discover-vw/golf-r-20th-anniversary.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/zodiac.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/car-naming.html
# https://vw.com/en/newsroom/lifestyle-and-heritage/color-trends-article.html
# https://vw.com/en/newsroom/discover-vw/get-to-know-the-id-buzz.html
# https://vw.com/en/newsroom/lifestyle-and-heritage
# https://vw.com/en/financial-services/explore-financing.html#lease-overview
# https://vw.com/en/financial-services/current-customers.html#service-your-vehicle
# https://vw.com/en/financial-services/ready-to-apply.html#apply-financing
# https://vw.com/en/financial-services/ready-to-apply.html#protection-products
# https://vw.com/en/financial-services/current-customers.html#make-a-payment
# https://vw.com/en/financial-services/explore-financing.html#pre-owned
# https://vw.com/en/financial-services/current-customers.html#lease-overview
# https://vw.com/en/financial-services/ready-to-apply.html#vw-insurance
# https://vw.com/en/financial-services/current-customers.html#service-vehicle-protection
# https://vw.com/en/financial-services/explore-financing.html#special-programs
# https://vw.com/en/carefree-shopping.html
# https://vw.com/es.html
# https://vw.com/es/software-update.html
# https://vw.com/es/privacy.html#online-advertising
# https://vw.com/es/newsroom/lifestyle-and-heritage/tiny-home-movement.html
# https://vw.com/es/newsroom/everything-electric/on-the-road-charging-experience.html
# https://vw.com/es/newsroom/everything-electric/things-to-do-while-charging.html
# https://vw.com/es/models/id-4.html
# https://vw.com/es/models/id-4.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/financial-services/take-it-ev.html
# https://vw.com/javascript:window.open("/es/builder.html/__app/id-4.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/id-4.app", "_self");' (found at least ' ')
# https://vw.com/es/electric-vehicles/electric-vehicles-articles.html#intro-evs
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/switch-to-ev.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/common-misconceptions-about-electric-vehicles.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/auto-shop-in-the-ev-era.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-batteries.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-charging-costs.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-owning-costs.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-range.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/what-you-want-in-your-electric-warranty.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-charging-time.html
# https://vw.com/es/electric-vehicles/electric-vehicles-articles/ev-fuel-economy.html
# https://vw.com/es/models/id-4.html/__layer/layers/showrooms/id_4/_2023/driver-assistance/master.layer
# https://vw.com/es/models/id-4.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/electric-vehicles/electric-vehicles-articles.html#inside-id4
# https://vw.com/es/iq-drive.html
# https://vw.com/es/models/tiguan.html
# https://vw.com/javascript:window.open("/es/builder.html/__app/tiguan.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/tiguan.app", "_self");' (found at least ' ')
# https://vw.com/es/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/tiguan.html/__layer/layers/showrooms/tiguan/_2023/driver-assistance/master.layer
# https://vw.com/es/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/es/models/tiguan.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/models/golf-gti.html
# https://vw.com/es/models/golf-gti.html/__layer/layers/showrooms/golf_gti/_2023/driver-assistance/master.layer
# https://vw.com/es/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/javascript:window.open("/es/builder.html/__app/golf-gti.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/golf-gti.app", "_self");' (found at least ' ')
# https://vw.com/es/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/golf-gti.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/es/models/taos.html
# https://vw.com/es/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/models/taos.html/__layer/layers/showrooms/taos/_2023/driver-assistance/master.layer
# https://vw.com/es/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/taos.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/javascript:window.open("/es/builder.html/__app/taos.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/taos.app", "_self");' (found at least ' ')
# https://vw.com/es/models/golf-r.html
# https://vw.com/javascript:window.open("/es/builder.html/__app/golf-r.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/golf-r.app", "_self");' (found at least ' ')
# https://vw.com/es/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/es/models/golf-r.html/__layer/layers/showrooms/golf_r/_2023/driver-assistance/master.layer
# https://vw.com/es/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/models/golf-r.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/arteon.html
# https://vw.com/es/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/javascript:window.open("/es/builder.html/__app/arteon.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/arteon.app", "_self");' (found at least ' ')
# https://vw.com/es/models/arteon.html/__layer/layers/showrooms/arteon/_2023/driver-assistance/master.layer
# https://vw.com/es/models/arteon.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/models/id-4.html/__layer/layers/showrooms/id_4/_2023/car-net-myvw-id-4/master.layer
# https://vw.com/es/models/id-buzz.html
# https://vw.com/es/models/id-7.html
# https://vw.com/es/models/id-7.html#form
# https://vw.com/es/models/id-buzz.html/__layer/layers/showrooms/id_buzz/reveal_1902959974/wallpapers/wallpapers/master.layer
# https://vw.com/es/suv.html
# https://vw.com/javascript:window.open("/es/offers.html?model=ID.4","_self");
# HTTP Error 404: Not Found
# https://vw.com/es/newsroom/everything-electric/ev-q-a.html
# https://vw.com/es/newsroom/everything-electric/ten-surprisingly-smart-features-on-the-Volkswagen-id-4-suv.html
# https://vw.com/es/newsroom/everything-electric/id-4-reveal.html
# https://vw.com/javascript:window.open(%22/es/builder.html/__app/id-4.app%22,%20%22_self%22);
# HTTP Error 404: Not Found
# https://vw.com/es/newsroom/discover-vw/iq-drive.html
# https://vw.com/es/newsroom/discover-vw/keeping-driving-fun-alive-in-the-2022-volkswagen-golf-gti-and-golf-r.html
# https://vw.com/es/newsroom/discover-vw/4-ways-volkswagen-helps-you-drive-carefree.html
# https://vw.com/es/newsroom/discover-vw/meet-vws-expanding-suv-lineup.html
# https://vw.com/es/newsroom/discover-vw/updating-the-2022-jetta-and-jetta-gli.html
# https://vw.com/es/newsroom/discover-vw.html
# https://vw.com/es/newsroom/discover-vw/specialists-preview-my23-vw-lineup.html
# https://vw.com/es/models/jetta-gli.html
# https://vw.com/es/models/jetta-gli.html/__layer/layers/showrooms/jetta_gli/_2023/driver-assistance/master.layer
# https://vw.com/javascript:window.open("/es/builder.html/__app/jetta-gli.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/jetta-gli.app", "_self");' (found at least ' ')
# https://vw.com/es/models/jetta-gli.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/jetta-gli.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/es/models/jetta-gli.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/newsroom/lifestyle-and-heritage/drive-bigger-upcycling.html
# https://vw.com/es/models/jetta.html
# https://vw.com/javascript:window.open("/es/builder.html/__app/jetta.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/jetta.app", "_self");' (found at least ' ')
# https://vw.com/es/models/jetta.html/__layer/layers/showrooms/jetta/_2023/driver-assistance/master.layer
# https://vw.com/es/models/jetta.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/apple-carplay/master.layer
# https://vw.com/es/models/jetta.html/__layer/layers/showrooms/shared_content/_2023/technology/app_connect/android-auto/master.layer
# https://vw.com/es/models/jetta.html/__layer/layers/showrooms/shared_content/_2023/technology/myvw/myvw/master.layer
# https://vw.com/es/models/id-4.html#faq
# https://vw.com/es/newsroom/future-of-mobility.html
# https://vw.com/es/newsroom/future-of-mobility/meb-v-mqb.html
# https://vw.com/es/newsroom/everything-electric/batteries.html
# https://vw.com/es/newsroom/everything-electric/vw-s-ev-history.html
# https://vw.com/es/newsroom/lifestyle-and-heritage/70-years-of-vw-in-the-u-s.html
# https://vw.com/es/newsroom/lifestyle-and-heritage
# https://vw.com/es/models/atlas.html/__layer/layers/showrooms/shared_content/_2024/technology/myvw/myvw/master.layer
# https://vw.com/javascript:window.open("/es/builder.html/__app/atlas.app", "_self");
# URL can't contain control characters. '/javascript:window.open("/es/builder.html/__app/atlas.app", "_self");' (found at least ' ')
# https://vw.com/es/models/atlas.html/__layer/layers/showrooms/atlas/_2024/driver-assistance/master.layer
# https://vw.com/es/models/atlas.html/__layer/layers/showrooms/shared_content/_2024/technology/app_connect/android-auto/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/theft-protection/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/multi-coverage/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/tire---wheel/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/cpo/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/lease-end-protection/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/term-protection/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/guaranteed-asset-protection/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/vehicle-service-protection/master.layer
# https://vw.com/es/financial-services/ready-to-apply.html/__layer/layers/vci/key-protection/master.layer
# https://vw.com/es/terms.html
# https://vw.com/es/builder.html
# https://vw.com/es/compact-cars.html
# https://vw.com/es/builder.html/__app/atlas.app
# https://vw.com/es/builder.html/__app/atlas/se-with-technology.app?category-app=private&carlineId-app=31691&salesGroupId-app=32911&trimName-app=SE+with+Technology&modelId-app=CA37PZ&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas/sel.app?category-app=private&carlineId-app=31691&salesGroupId-app=32913&trimName-app=SEL&modelId-app=CA34PR&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas/sel-premium-r-line.app?category-app=private&carlineId-app=31691&salesGroupId-app=32915&trimName-app=SEL+Premium+R-Line&modelId-app=CA35PR&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas/se.app?category-app=private&carlineId-app=31691&salesGroupId-app=32910&trimName-app=SE&modelId-app=CA33PZ&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/id-4.app
# https://vw.com/es/builder.html/__app/id-4/id-4-pro-s-plus.app?category-app=private&carlineId-app=30291&salesGroupId-app=31816&trimName-app=ID.4+Pro+S+Plus&modelId-app=E813MN%24MAAUE0A%24GP00P00%24MRELV0A%24GW02W02&modelVersion-app=4&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-awd-pro.app?category-app=private&carlineId-app=30291&salesGroupId-app=31812&trimName-app=ID.4+AWD+Pro&modelId-app=E813SN%24MRELV0A&modelVersion-app=5&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-awd-pro-s-plus.app?category-app=private&carlineId-app=30291&salesGroupId-app=31817&trimName-app=ID.4+AWD+Pro+S+Plus&modelId-app=E813SN%24MAAUE0A%24GP00P00%24MRELV0A%24GW02W02&modelVersion-app=5&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-pro-s.app?category-app=private&carlineId-app=30291&salesGroupId-app=31814&trimName-app=ID.4+Pro+S&modelId-app=E813MN%24MAAUE0A%24MRELV0A%24GW02W02&modelVersion-app=4&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-s.app?category-app=private&carlineId-app=30291&salesGroupId-app=31813&trimName-app=ID.4+S&modelId-app=E812MJ%24MAAUE0A%24MRELV0A%24GW01W01&modelVersion-app=4&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-pro.app?category-app=private&carlineId-app=30291&salesGroupId-app=31811&trimName-app=ID.4+Pro&modelId-app=E813MN%24MRELV0A&modelVersion-app=4&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-standard.app?category-app=private&carlineId-app=30291&salesGroupId-app=31810&trimName-app=ID.4+Standard&modelId-app=E812MJ%24MRELV0A&modelVersion-app=4&modelYear-app=2023
# https://vw.com/es/builder.html/__app/id-4/id-4-awd-pro-s.app?category-app=private&carlineId-app=30291&salesGroupId-app=31815&trimName-app=ID.4+AWD+Pro+S&modelId-app=E813SN%24MAAUE0A%24MRELV0A%24GW02W02&modelVersion-app=5&modelYear-app=2023
# https://vw.com/es/builder.html/__app/jetta-gli.app
# https://vw.com/es/builder.html/__app/jetta-gli/autobahn.app?category-app=private&carlineId-app=30907&salesGroupId-app=31875&trimName-app=Autobahn&modelId-app=BU49V2&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/sedans.html
# https://vw.com/es/builder.html/__app/tiguan.app
# https://vw.com/es/builder.html/__app/tiguan/se-r-line-black.app?category-app=private&carlineId-app=31120&salesGroupId-app=31892&trimName-app=SE+R-Line+Black&modelId-app=BJ2VVS&modelVersion-app=2&modelYear-app=2023
# https://vw.com/es/builder.html/__app/tiguan/s.app?category-app=private&carlineId-app=31120&salesGroupId-app=31890&trimName-app=S&modelId-app=BJ22VS&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/tiguan/se.app?category-app=private&carlineId-app=31120&salesGroupId-app=31891&trimName-app=SE&modelId-app=BJ23VS&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/tiguan/sel-r-line.app?category-app=private&carlineId-app=31120&salesGroupId-app=31893&trimName-app=SEL+R-Line&modelId-app=BJ24VJ&modelVersion-app=2&modelYear-app=2023
# https://vw.com/es/builder.html/__app/taos.app
# https://vw.com/es/builder.html/__app/taos/s.app?category-app=private&carlineId-app=30385&salesGroupId-app=31860&trimName-app=S&modelId-app=CL12RZ&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/taos/se.app?category-app=private&carlineId-app=30385&salesGroupId-app=31861&trimName-app=SE&modelId-app=CL13RZ&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/taos/sel.app?category-app=private&carlineId-app=30385&salesGroupId-app=31862&trimName-app=SEL&modelId-app=CL14RT&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/atlas-cross-sport.app
# https://vw.com/es/builder.html/__app/atlas-cross-sport/se.app?category-app=private&carlineId-app=31692&salesGroupId-app=32920&trimName-app=SE&modelId-app=CMD3PZ&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas-cross-sport/sel-premium-r-line.app?category-app=private&carlineId-app=31692&salesGroupId-app=32924&trimName-app=SEL+Premium+R-Line&modelId-app=CMD5PR&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas-cross-sport/sel.app?category-app=private&carlineId-app=31692&salesGroupId-app=32922&trimName-app=SEL&modelId-app=CMD4PR&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas-cross-sport/sel-r-line.app?category-app=private&carlineId-app=31692&salesGroupId-app=32923&trimName-app=SEL+R-Line&modelId-app=CMD4PR%24GP51P51&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/atlas-cross-sport/se-with-technology.app?category-app=private&carlineId-app=31692&salesGroupId-app=32921&trimName-app=SE+with+Technology&modelId-app=CMD7PZ&modelVersion-app=1&modelYear-app=2024
# https://vw.com/es/builder.html/__app/arteon.app
# https://vw.com/es/builder.html/__app/arteon/se-r-line.app?category-app=private&carlineId-app=31500&salesGroupId-app=31900&trimName-app=SE+R-Line&modelId-app=3H82RZ&modelVersion-app=0&modelYear-app=2023
# https://vw.com/es/builder.html/__app/arteon/sel-r-line.app?category-app=private&carlineId-app=31500&salesGroupId-app=31901&trimName-app=SEL+R-Line&modelId-app=3H82RT&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/arteon/sel-premium-r-line.app?category-app=private&carlineId-app=31500&salesGroupId-app=31902&trimName-app=SEL+Premium+R-Line&modelId-app=3H82RT%24GP05P05&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/jetta.app
# https://vw.com/es/builder.html/__app/jetta/sport.app?category-app=private&carlineId-app=30906&salesGroupId-app=31871&trimName-app=Sport&modelId-app=BU42R2&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/jetta/sel.app?category-app=private&carlineId-app=30906&salesGroupId-app=31873&trimName-app=SEL&modelId-app=BU44RS&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/jetta/se.app?category-app=private&carlineId-app=30906&salesGroupId-app=31872&trimName-app=SE&modelId-app=BU43RS&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/jetta/s.app?category-app=private&carlineId-app=30906&salesGroupId-app=31870&trimName-app=S&modelId-app=BU41R2&modelVersion-app=3&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-gti.app
# https://vw.com/es/builder.html/__app/golf-gti/s.app?category-app=private&carlineId-app=30320&salesGroupId-app=31845&trimName-app=S&modelId-app=CD19U2&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-gti/autobahn.app?category-app=private&carlineId-app=30320&salesGroupId-app=31848&trimName-app=Autobahn&modelId-app=CD19U2%24GWO5WO5&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-gti/40th-anniversary-edition.app?category-app=private&carlineId-app=30320&salesGroupId-app=31846&trimName-app=40th+Anniversary+Edition&modelId-app=CD19U2%24MAAUE3A%24GWO3WO3&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-gti/se.app?category-app=private&carlineId-app=30320&salesGroupId-app=31847&trimName-app=SE&modelId-app=CD19U2%24GWO4WO4&modelVersion-app=1&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-r.app
# https://vw.com/es/builder.html/__app/golf-r/golf-r.app?category-app=private&carlineId-app=30310&salesGroupId-app=31840&trimName-app=Golf+R&modelId-app=CD1RM4&modelVersion-app=0&modelYear-app=2023
# https://vw.com/es/builder.html/__app/golf-r/golf-r-20th-anniversary-edition.app?category-app=private&carlineId-app=30310&salesGroupId-app=31841&trimName-app=Golf+R+20th+Anniversary+Edition&modelId-app=CD1RM4%24MAAUE4R%24GWOAWOA&modelVersion-app=0&modelYear-app=2023
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 crawl(full_url)
#
# Cell In[1], line 115, in crawl(url)
#     112 print(url) # for debugging and to see the progress
#     114 # Save text from the url to a <url>.txt file
# --> 115 with open('text/'+local_domain+'/'+url[8:].replace("/", "_") + ".txt", "w") as f:
#     116
#     117     # Get the text from the URL using BeautifulSoup
#     118     soup = BeautifulSoup(requests.get(url).text, "html.parser")
#     120     # Get the text but remove the tags
#
# File /workspace/openai-cookbook/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 36] File name too long: 'text/vw.com/vw.com_es_builder.html___app_golf-r_golf-r-20th-anniversary-edition.app?category-app=private&carlineId-app=30310&salesGroupId-app=31841&trimName-app=Golf+R+20th+Anniversary+Edition&modelId-app=CD1RM4%24MAAUE4R%24GWOAWOA&modelVersion-app=0&modelYear-app=2023.txt'

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

# Get all the text files in the text directory
for file in os.listdir("text/" + domain + "/"):

    # Open the file and read the text
    with open("text/" + domain + "/" + file, "r") as f:
        text = f.read()

        # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
        texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()
# Out:
# /tmp/ipykernel_610/2931785837.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   serie = serie.str.replace('\\n', ' ')
#                            fname  \
# 0
# 1                  tml?open=true
# 2          arefree shopping.html
# 3               ompact cars.html
# 4  ontact.html#volkswagen credit
#
#                                                 text
# 0  .  VW.com | Official Home of Volkswagen Cars &...
# 1  tml?open=true.  VW.com | Official Home of Volk...
# 2  arefree shopping.html.  Volkswagen Carefree Sh...
# 3  ompact cars.html.  VW Compact Cars | Volkswage...
# 4  ontact.html#volkswagen credit.  Contact Us    ...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv('processed/scraped.csv', index_col=0)
df.columns = ['title', 'text']

# Tokenize the text and save the number of tokens to a new column
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
max_tokens = 500

# Function to split the text into chunks of a maximum number of tokens
def split_into_many(text, max_tokens = max_tokens):

    # Split the text into sentences
    sentences = text.split('. ')

    # Get the number of tokens for each sentence
    n_tokens = [len(tokenizer.encode(" " + sentence)) for sentence in sentences]
    
    chunks = []
    tokens_so_far = 0
    chunk = []

    # Loop through the sentences and tokens joined together in a tuple
    for sentence, token in zip(sentences, n_tokens):

        # If the number of tokens so far plus the number of tokens in the current sentence is greater 
        # than the max number of tokens, then add the chunk to the list of chunks and reset
        # the chunk and tokens so far
        if tokens_so_far + token > max_tokens:
            chunks.append(". ".join(chunk) + ".")
            chunk = []
            tokens_so_far = 0

        # If the number of tokens in the current sentence is greater than the max number of 
        # tokens, go to the next sentence
        if token > max_tokens:
            continue

        # Otherwise, add the sentence to the chunk and add the number of tokens to the total
        chunk.append(sentence)
        tokens_so_far += token + 1

    return chunks
    

shortened = []

# Loop through the dataframe
for row in df.iterrows():

    # If the text is None, go to the next row
    if row[1]['text'] is None:
        continue

    # If the number of tokens is greater than the max number of tokens, split the text into chunks
    if row[1]['n_tokens'] > max_tokens:
        shortened += split_into_many(row[1]['text'])
    
    # Otherwise, add the text to the list of shortened texts
    else:
        shortened.append( row[1]['text'] )

# %%
df = pd.DataFrame(shortened, columns = ['text'])
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
import openai
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

df['embeddings'] = df.text.apply(lambda x: openai.Embedding.create(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
df.to_csv('processed/embeddings.csv')
df.head()
# Out:
#                                                 text  n_tokens  \
# 0  .  VW.com | Official Home of Volkswagen Cars &...       406
# 1  Oh, and qualifying individuals may be eligible...       497
# 2  tml?open=true.  VW.com | Official Home of Volk...       410
# 3  Oh, and qualifying individuals may be eligible...       497
# 4  arefree shopping.html.  Volkswagen Carefree Sh...       498
#
#                                           embeddings
# 0  [-0.0037561419885605574, -0.001591952051967382...
# 1  [-0.0069680227898061275, -0.005096797831356525...
# 2  [-0.002821777481585741, -0.003312015673145652,...
# 3  [-0.0069680227898061275, -0.005096797831356525...
# 4  [-0.0034374769311398268, 0.002078855177387595,...

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from openai.embeddings_utils import distances_from_embeddings, cosine_similarity

df=pd.read_csv('processed/embeddings.csv', index_col=0)
df['embeddings'] = df['embeddings'].apply(literal_eval).apply(np.array)

df.head()
# Out:
#                                                 text  n_tokens  \
# 0  .  VW.com | Official Home of Volkswagen Cars &...       406
# 1  Oh, and qualifying individuals may be eligible...       497
# 2  tml?open=true.  VW.com | Official Home of Volk...       410
# 3  Oh, and qualifying individuals may be eligible...       497
# 4  arefree shopping.html.  Volkswagen Carefree Sh...       498
#
#                                           embeddings
# 0  [-0.0037561419885605574, -0.001591952051967382...
# 1  [-0.0069680227898061275, -0.005096797831356525...
# 2  [-0.002821777481585741, -0.003312015673145652,...
# 3  [-0.0069680227898061275, -0.005096797831356525...
# 4  [-0.0034374769311398268, 0.002078855177387595,...

# %%
def create_context(
    question, df, max_len=1800, size="ada"
):
    """
    Create a context for a question by finding the most similar context from the dataframe
    """

    # Get the embeddings for the question
    q_embeddings = openai.Embedding.create(input=question, engine='text-embedding-ada-002')['data'][0]['embedding']

    # Get the distances from the embeddings
    df['distances'] = distances_from_embeddings(q_embeddings, df['embeddings'].values, distance_metric='cosine')


    returns = []
    cur_len = 0

    # Sort by distance and add the text to the context until the context is too long
    for i, row in df.sort_values('distances', ascending=True).iterrows():
        
        # Add the length of the text to the current length
        cur_len += row['n_tokens'] + 4
        
        # If the context is too long, break
        if cur_len > max_len:
            break
        
        # Else add it to the text that is being returned
        returns.append(row["text"])

    # Return the context
    return "\n\n###\n\n".join(returns)

def answer_question(
    df,
    model="text-davinci-003",
    question="Am I allowed to publish model outputs to Twitter, without a human review?",
    max_len=1800,
    size="ada",
    debug=False,
    max_tokens=150,
    stop_sequence=None
):
    """
    Answer a question based on the most similar context from the dataframe texts
    """
    context = create_context(
        question,
        df,
        max_len=max_len,
        size=size,
    )
    # If debug, print the raw model response
    if debug:
        print("Context:\n" + context)
        print("\n\n")

    try:
        # Create a completions using the question and context
        response = openai.Completion.create(
            prompt=f"Answer the question based on the context below, and if the question can't be answered based on the context, say \"I don't know\"\n\nContext: {context}\n\n---\n\nQuestion: {question}\nAnswer:",
            temperature=0,
            max_tokens=max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=stop_sequence,
            model=model,
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
answer_question(df, question="What day is it?", debug=False)
# Out:
# "I don't know."

# %%
answer_question(df, question="What is our newest model?", debug=True)
# Out:
# Context:
# odels golf gti.html   layer layers showrooms shared content  2023 technology app connect apple carplay master.layer.  2023 Golf GTI from Volkswagen       Skip to main contentSkip to footerMenuVolkswagenModelsBuilderElectric VehiclesID.4ID. BuzzID.7Electric Vehicle ArticlesEV CalculatorOur Values and ActionsInventoryCertified Used InventoryOffersFind A Volkswagen DealermyVWFinancial ServicesExplore FinancingHow to ApplyCurrent CustomersOur Values and ActionsContact UsGolf GTIBuild your Golf GTIStarting MSRP$30,530⁠1Horsepower241Torque273 lbs-ftAvailableIQ.DRIVE⁠2Request a QuoteHomeModelsGolf GTIRecognized power and performanceThe 2022 Golf GTI was named a Best New Car by AutotraderWith its compelling tech, modern looks, and powerful turbocharged engine with 6-speed manual transmission, is it surprising that the industry continues to recognize this model? Not for Golf GTI owners. Just check their smiles.⁠3See what Autotrader had to sayOpens an external linkBursting at the hatch with power40 years ago, the Golf GTI began carving out its fun-to-drive reputation in the U.S. Today’s eighth generation packs exhilarating power, and the latest, driver-focused technology into a concentrated, sporty design, delivering on the promise we made–to keep it fun, always.PerformanceOverviewMore fun-to-drive than ever beforeThe Golf GTI has been taking fun seriously for 40 years.
#
# ###
#
# odels golf gti.html   layer layers showrooms shared content  2023 technology app connect android auto master.layer.  2023 Golf GTI from Volkswagen       Skip to main contentSkip to footerMenuVolkswagenModelsBuilderElectric VehiclesID.4ID. BuzzID.7Electric Vehicle ArticlesEV CalculatorOur Values and ActionsInventoryCertified Used InventoryOffersFind A Volkswagen DealermyVWFinancial ServicesExplore FinancingHow to ApplyCurrent CustomersOur Values and ActionsContact UsGolf GTIBuild your Golf GTIStarting MSRP$30,530⁠1Horsepower241Torque273 lbs-ftAvailableIQ.DRIVE⁠2Request a QuoteHomeModelsGolf GTIRecognized power and performanceThe 2022 Golf GTI was named a Best New Car by AutotraderWith its compelling tech, modern looks, and powerful turbocharged engine with 6-speed manual transmission, is it surprising that the industry continues to recognize this model? Not for Golf GTI owners. Just check their smiles.⁠3See what Autotrader had to sayOpens an external linkBursting at the hatch with power40 years ago, the Golf GTI began carving out its fun-to-drive reputation in the U.S. Today’s eighth generation packs exhilarating power, and the latest, driver-focused technology into a concentrated, sporty design, delivering on the promise we made–to keep it fun, always.PerformanceOverviewMore fun-to-drive than ever beforeThe Golf GTI has been taking fun seriously for 40 years.
#
# ###
#
# odels golf gti.html   layer layers showrooms golf gti  2023 driver assistance master.layer.  2023 Golf GTI from Volkswagen       Skip to main contentSkip to footerMenuVolkswagenModelsBuilderElectric VehiclesID.4ID. BuzzID.7Electric Vehicle ArticlesEV CalculatorOur Values and ActionsInventoryCertified Used InventoryOffersFind A Volkswagen DealermyVWFinancial ServicesExplore FinancingHow to ApplyCurrent CustomersOur Values and ActionsContact UsGolf GTIBuild your Golf GTIStarting MSRP$30,530⁠1Horsepower241Torque273 lbs-ftAvailableIQ.DRIVE⁠2Request a QuoteHomeModelsGolf GTIRecognized power and performanceThe 2022 Golf GTI was named a Best New Car by AutotraderWith its compelling tech, modern looks, and powerful turbocharged engine with 6-speed manual transmission, is it surprising that the industry continues to recognize this model? Not for Golf GTI owners. Just check their smiles.⁠3See what Autotrader had to sayOpens an external linkBursting at the hatch with power40 years ago, the Golf GTI began carving out its fun-to-drive reputation in the U.S. Today’s eighth generation packs exhilarating power, and the latest, driver-focused technology into a concentrated, sporty design, delivering on the promise we made–to keep it fun, always.PerformanceOverviewMore fun-to-drive than ever beforeThe Golf GTI has been taking fun seriously for 40 years.
#
# ###
#
# odels golf gti.html   layer layers showrooms shared content  2023 technology myvw myvw master.layer.  2023 Golf GTI from Volkswagen       Skip to main contentSkip to footerMenuVolkswagenModelsBuilderElectric VehiclesID.4ID. BuzzID.7Electric Vehicle ArticlesEV CalculatorOur Values and ActionsInventoryCertified Used InventoryOffersFind A Volkswagen DealermyVWFinancial ServicesExplore FinancingHow to ApplyCurrent CustomersOur Values and ActionsContact UsGolf GTIBuild your Golf GTIStarting MSRP$30,530⁠1Horsepower241Torque273 lbs-ftAvailableIQ.DRIVE⁠2Request a QuoteHomeModelsGolf GTIRecognized power and performanceThe 2022 Golf GTI was named a Best New Car by AutotraderWith its compelling tech, modern looks, and powerful turbocharged engine with 6-speed manual transmission, is it surprising that the industry continues to recognize this model? Not for Golf GTI owners. Just check their smiles.⁠3See what Autotrader had to sayOpens an external linkBursting at the hatch with power40 years ago, the Golf GTI began carving out its fun-to-drive reputation in the U.S. Today’s eighth generation packs exhilarating power, and the latest, driver-focused technology into a concentrated, sporty design, delivering on the promise we made–to keep it fun, always.PerformanceOverviewMore fun-to-drive than ever beforeThe Golf GTI has been taking fun seriously for 40 years.
#
# ###
#
# odels id buzz.html   layer layers showrooms id buzz reveal 1902959974 wallpapers wallpapers master.layer.  The ID. Buzz from Volkswagen       Skip to main contentSkip to footerMenuVolkswagenModelsBuilderElectric VehiclesID.4ID. BuzzID.7Electric Vehicle ArticlesEV CalculatorOur Values and ActionsInventoryCertified Used InventoryOffersFind A Volkswagen DealermyVWFinancial ServicesExplore FinancingHow to ApplyCurrent CustomersOur Values and ActionsContact UsResurfacedThe comeback we’ve all been waiting for is here. In case you couldn’t tell, we’re talking about the bus. The VW ID. Buzz, that is. And it’s making its way to the U.S. in 2024.Stay plugged in The comeback we’ve all been waiting for is here. In case you couldn’t tell, we’re talking about the bus. The VW ID. Buzz, that is. And it’s making its way to the U.S. in 2024.HomeModelsThe ID. BuzzOld-school cool meets new-school fuel C’mon. There’s no gas. The ID. Buzz is electric. Who needs gas anyways, with this much going on? Like three rows, that offer six and seven seat configurations. You can fit an entire volleyball team inside. Now that’s spacious. And the style is rather eye-catching. Look at the two-tone paint. You’ll definitely never lose it in a parking lot. We could go on about our new bus, but we think you get the drift., 1 of 4, 2 of 4, 3 of 4, 4 of 4FAQsWhen will the ID. Buzz arrive at dealers in the U.S.? The ID. Buzz will arrive at dealers in 2024. Fill out the short form on the ID. Buzz page on vw.com to get updates prior to the ID. Buzz arrival.How big is the ID. Buzz?The ID. Buzz is about the same length and width as our Atlas Cross Sport. It is roughly 195” in length, 78” in width and 75” in height.
# 'The ID. Buzz from Volkswagen.'
